# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ENAMINE = pd.read_csv("../data/Enamine/Enamine_Hit_Locator_Library_100K_Set_plated_100160cmpds_20250629.smiles", sep='\t')
mws = ENAMINE['MW (desalted)'].tolist()

# %%
plt.hist(mws, bins=[i for i in range(200, 600, 10)], ec='k')
plt.show()

# %%
np.percentile(mws, 5)
# Out:
# np.float64(270.33)

# %%
np.percentile(mws, 94)
# Out:
# np.float64(400.471)
