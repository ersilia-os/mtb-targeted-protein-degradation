# %%
# import shutil
# import joblib
# import os

# %%
# # Define paths
# PATH_TO_ALOY = "/aloy/home/acomajuncosa/Ersilia/mtb/processed/unidock_docking/models"
# PATH_TO_HERBERT = "../processed/unidock_docking/models"
# os.makedirs(PATH_TO_HERBERT, exist_ok=True)
# bins = ['bin_1', 'bin_05', 'bin_01']

# # For each pocket structure
# for st in sorted(os.listdir(PATH_TO_ALOY)):

#     # For each bin
#     for bin in bins:

#         # If model does not exist, report it
#         if os.path.exists(os.path.join(PATH_TO_ALOY, st, bin, "LQ_RF.joblib")) == False:
#             print(st, bin)

#         else:
#             # Copy AUROCs
#             os.makedirs(os.path.join(PATH_TO_HERBERT, st, bin), exist_ok=True)
#             shutil.copyfile(os.path.join(PATH_TO_ALOY, st, bin, "AUROCs.csv"), os.path.join(PATH_TO_HERBERT, st, bin, "AUROCs.csv"))

#             # Copy bin_01 model -- gitignored
#             if bin == 'bin_01':
#                 pass
#                 # shutil.copyfile(os.path.join(PATH_TO_ALOY, st, bin, "LQ_RF.joblib"), os.path.join(PATH_TO_HERBERT, st, bin, "LQ_RF.joblib"))


#     break

# mdl = joblib.load(os.path.join(PATH_TO_HERBERT, st, bin, "LQ_RF.joblib"))
# mdl = joblib.load(os.path.join(PATH_TO_ALOY, st, bin, "LQ_RF.joblib"))
