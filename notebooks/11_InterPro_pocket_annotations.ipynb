# %%
import pandas as pd

# %%
pocket_detection_interpro_df = pd.read_csv("../processed/pocket_detection_data_interpro.tsv", sep="\t")

# Hide unnecessary columns
del pocket_detection_interpro_df['Pocket centroid coordinate (x y z)']
del pocket_detection_interpro_df['Pocket residues (chain_resn)']
del pocket_detection_interpro_df['B-factors']
del pocket_detection_interpro_df['Full path']
del pocket_detection_interpro_df['Interpro Matches']

# Add "pocket ID" column
pocket_detection_interpro_df['Pocket ID'] = ["-".join([i,j.strip(".pdb"),f"pocket{k}"]) 
                                             for i,j,k in zip(pocket_detection_interpro_df['Uniprot AC'], 
                                             pocket_detection_interpro_df['File name'], 
                                             pocket_detection_interpro_df['Pocket number'])]

# %%
### 1 overlap ###

# %%
curated_annotation = "Catalytic Domain (ATP Binding Site)"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Catalytic Domain (ATP Binding Site)' annotation: 168

# %%
curated_annotation = "Anticodon Binding Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Anticodon Binding Domain' annotation: 34

# %%
curated_annotation = "Editing Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Editing Domain' annotation: 48

# %%
curated_annotation = "tRNA Binding Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'tRNA Binding Domain' annotation: 12

# %%
curated_annotation = "RNA Binding Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'RNA Binding Domain' annotation: 0

# %%
curated_annotation = "Other too broad/unspecified functional entities"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Other too broad/unspecified functional entities' annotation: 133

# %%
curated_annotation = "Other"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] > 0) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Other' annotation: 8

# %%
### N overlap ###

N = 5

# %%
curated_annotation = "Catalytic Domain (ATP Binding Site)"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Catalytic Domain (ATP Binding Site)' annotation: 136

# %%
curated_annotation = "Anticodon Binding Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Anticodon Binding Domain' annotation: 29

# %%
curated_annotation = "Editing Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Editing Domain' annotation: 41

# %%
curated_annotation = "tRNA Binding Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'tRNA Binding Domain' annotation: 9

# %%
curated_annotation = "RNA Binding Domain"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'RNA Binding Domain' annotation: 0

# %%
curated_annotation = "Other too broad/unspecified functional entities"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Other too broad/unspecified functional entities' annotation: 91

# %%
curated_annotation = "Other"
pockets = pocket_detection_interpro_df[(pocket_detection_interpro_df['Residues overlap'] >= N) & 
                                       (pocket_detection_interpro_df['Interpro curated annotation'] == curated_annotation)]
pockets = set(pockets['Pocket ID'])
print(f"Pockets overlapping with Interpro '{curated_annotation}' annotation: {len(pockets)}")
# Out:
# Pockets overlapping with Interpro 'Other' annotation: 3
