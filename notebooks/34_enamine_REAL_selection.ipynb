# %%
from collections import Counter
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np
import pickle
import os

# %%
# Load labels and pockets
root = '.'
PATH_TO_PROBS = os.path.join(root, "..", "processed", "unidock_docking", "inference_probs")
labels = np.array(pickle.load(open(os.path.join(PATH_TO_PROBS, "success_mols.pkl"), "rb")))
pockets = [i.replace("_bin_01.npz", "") for i in sorted(os.listdir(PATH_TO_PROBS)) if i != "success_mols.pkl"]
success_mols = np.array(pickle.load(open(os.path.join(PATH_TO_PROBS, "success_mols.pkl"), "rb")))
assert (success_mols == labels).all()

print(f"Number of pockets: {len(pockets)}")
print(f"Number of unique molecules: {len(set(labels))}")

# Load probabilities
print("Loading probabilities...")
pocket_to_all_probs = {}
for c, pocket in tqdm(enumerate(pockets)):
    probs = np.load(os.path.join(PATH_TO_PROBS, f"{pocket}_bin_01.npz"))["arr_0"]
    pocket_to_all_probs[pocket] = probs

# Prepare matrix
M = np.column_stack([pocket_to_all_probs[p] for p in pockets])
del pocket_to_all_probs
print(f"Matrix shape: {M.shape}")
print("Normalizing by columns...")
means_1 = np.mean(M, axis=0, keepdims=True)
stds_1 = np.std(M, axis=0, keepdims=True)
M -= means_1
M /= stds_1

print("Normalizing by rows...")
means_2 = np.mean(M, axis=1, keepdims=True)
stds_2 = np.std(M, axis=1, keepdims=True)
M -= means_2
M /= stds_2

print(f"Matrix loaded, shape: {M.shape}")
# Out:
# Number of pockets: 276
# Number of unique molecules: 9556875
# Loading probabilities...
# 276it [00:54,  5.02it/s]
# Matrix shape: (9556875, 276)
# Normalizing by columns...
# Normalizing by rows...
# Matrix loaded, shape: (9556875, 276)

# %%
# Load smiles
df = pd.read_csv(os.path.join(root, "..", "processed", "enamine_REAL_characterization", "enamine_REAL.tsv"), sep='\t')

# From compound ID to SMILES
synthons = {i: j for i, j in zip(df['id'], df['smiles'])}

# Dictionary with counts of each synthon
syns_counter = dict(Counter([j for i in synthons for j in i.split("____")[1:]]))

print(f"Number of unique 'synthons': {len(syns_counter)}")
print(f"1 occ: {len([i for i in syns_counter if syns_counter[i] == 1])}")
print(f">100 occ: {len([i for i in syns_counter if syns_counter[i] > 100])}")
print(f">1000 occ: {len([i for i in syns_counter if syns_counter[i] > 1000])}")
print(f"MAX occ: {max(syns_counter.values())}")

del df, synthons
# Out:
# Number of unique 'synthons': 1299755
# 1 occ: 350697
# >100 occ: 32236
# >1000 occ: 2806
# MAX occ: 22418

# %%
# Get indices that sort every column
inds = {}
for col in tqdm(range(M.shape[1])):
    inds[col] = np.argsort(M[:, col])[::-1].astype(np.int32)

# Remove huge matrix M from memory
del M
# Out:
# 100%|██████████| 276/276 [03:21<00:00,  1.37it/s]

# %%
MAX_MOL = 100000
MAX_SYN = 5

ALL_CONSIDERED_MOLECULES = {}
ALL_CONSIDERED_SYNTHONS = {}

for c1, pocket in enumerate(pockets):

    # Molecules sorted
    sorted_molecules = labels[inds[c1]]

    # Counting synthons in the sorted molecules
    syns_counter_tmp = {i: 0 for i in syns_counter}
    considered_molecules = []

    # For each molecule
    for c2, mol in enumerate(sorted_molecules):

        syns = mol.split("____")[1:]
        include = [syns_counter_tmp[syn] < MAX_SYN for syn in syns]

        # If we can include the molecule
        if all(include) == True:
            considered_molecules.append(mol)
            for syn in syns:
                syns_counter_tmp[syn] += 1

        # If we can not include the molecule
        else:
            continue

        # If we have reached MAX_MOL
        if len(considered_molecules) >= MAX_MOL:
            break
    
    # Sanity check
    syns = [syn for mol in considered_molecules for syn in mol.split("____")[1:]]
    syns = dict(Counter(syns))
    assert all([syns[i] <= MAX_SYN for i in syns])

    print("\n")
    print(f"Pocket model: {pocket}")
    print(f"Number of considered molecules: {len(considered_molecules)}")
    print(f"Number of evaluated molecules: {c2+1}")
    print(f"Number of considered synthons: {len(syns)}")

    ALL_CONSIDERED_MOLECULES[pocket] = set(considered_molecules)
    ALL_CONSIDERED_SYNTHONS[pocket] = set(syns)
# Out:
# Pocket model: alphafold2_P9WFS9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 195204
# Number of considered synthons: 138439
#
#
# Pocket model: alphafold2_P9WFS9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 278870
# Number of considered synthons: 132244
#
#
# Pocket model: alphafold2_P9WFS9_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 237163
# Number of considered synthons: 130375
#
#
# Pocket model: alphafold2_P9WFS9_model_0_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 439101
# Number of considered synthons: 135897
#
#
# Pocket model: alphafold2_P9WFS9_model_0_pocket_5
# Number of considered molecules: 100000
# Number of evaluated molecules: 156386
# Number of considered synthons: 114163
#
#
# Pocket model: alphafold2_P9WFT1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 311910
# Number of considered synthons: 131866
#
#
# Pocket model: alphafold2_P9WFT1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 162788
# Number of considered synthons: 121842
#
#
# Pocket model: alphafold2_P9WFT3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 231614
# Number of considered synthons: 128217
#
#
# Pocket model: alphafold2_P9WFT3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 475955
# Number of considered synthons: 126986
#
#
# Pocket model: alphafold2_P9WFT5_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 195846
# Number of considered synthons: 120629
#
#
# Pocket model: alphafold2_P9WFT7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 271433
# Number of considered synthons: 125363
#
#
# Pocket model: alphafold2_P9WFT7_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 190089
# Number of considered synthons: 127391
#
#
# Pocket model: alphafold2_P9WFT9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 253447
# Number of considered synthons: 124748
#
#
# Pocket model: alphafold2_P9WFU1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 294749
# Number of considered synthons: 136792
#
#
# Pocket model: alphafold2_P9WFU1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 274174
# Number of considered synthons: 122868
#
#
# Pocket model: alphafold2_P9WFU3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 219523
# Number of considered synthons: 133094
#
#
# Pocket model: alphafold2_P9WFU3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 374235
# Number of considered synthons: 134960
#
#
# Pocket model: alphafold2_P9WFU5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 260884
# Number of considered synthons: 132996
#
#
# Pocket model: alphafold2_P9WFU5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 263224
# Number of considered synthons: 129280
#
#
# Pocket model: alphafold2_P9WFU9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 281968
# Number of considered synthons: 132288
#
#
# Pocket model: alphafold2_P9WFV1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 234918
# Number of considered synthons: 136235
#
#
# Pocket model: alphafold2_P9WFV1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 378111
# Number of considered synthons: 132159
#
#
# Pocket model: alphafold2_P9WFV1_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 252897
# Number of considered synthons: 131339
#
#
# Pocket model: alphafold2_P9WFV1_model_0_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 235765
# Number of considered synthons: 126953
#
#
# Pocket model: alphafold2_P9WFV3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 334218
# Number of considered synthons: 129719
#
#
# Pocket model: alphafold2_P9WFV3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 267975
# Number of considered synthons: 146312
#
#
# Pocket model: alphafold2_P9WFV3_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 259677
# Number of considered synthons: 125632
#
#
# Pocket model: alphafold2_P9WFV5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 397962
# Number of considered synthons: 127251
#
#
# Pocket model: alphafold2_P9WFV5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 411702
# Number of considered synthons: 127991
#
#
# Pocket model: alphafold2_P9WFV7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 193192
# Number of considered synthons: 132047
#
#
# Pocket model: alphafold2_P9WFV7_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 277267
# Number of considered synthons: 134539
#
#
# Pocket model: alphafold2_P9WFV9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 394524
# Number of considered synthons: 130846
#
#
# Pocket model: alphafold2_P9WFV9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 230355
# Number of considered synthons: 126539
#
#
# Pocket model: alphafold2_P9WFW1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 198483
# Number of considered synthons: 131217
#
#
# Pocket model: alphafold2_P9WFW3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 188654
# Number of considered synthons: 132513
#
#
# Pocket model: alphafold2_P9WFW3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 360755
# Number of considered synthons: 124144
#
#
# Pocket model: alphafold2_P9WFW5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 263111
# Number of considered synthons: 126492
#
#
# Pocket model: alphafold2_P9WFW5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 237556
# Number of considered synthons: 132495
#
#
# Pocket model: alphafold2_P9WFW7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 227375
# Number of considered synthons: 135716
#
#
# Pocket model: alphafold2_P9WFW7_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 269894
# Number of considered synthons: 134705
#
#
# Pocket model: alphafold2_P9WFW7_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 545666
# Number of considered synthons: 131196
#
#
# Pocket model: alphafold2_P9WFW7_model_0_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 550911
# Number of considered synthons: 132338
#
#
# Pocket model: alphafold2_P9WN61_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 359575
# Number of considered synthons: 142796
#
#
# Pocket model: alphafold2_P9WQA1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 379880
# Number of considered synthons: 127010
#
#
# Pocket model: alphafold2_P9WQA1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 147053
# Number of considered synthons: 126792
#
#
# Pocket model: alphafold3_P9WFS9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 202002
# Number of considered synthons: 130246
#
#
# Pocket model: alphafold3_P9WFS9_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 234565
# Number of considered synthons: 129715
#
#
# Pocket model: alphafold3_P9WFS9_model_0_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 404694
# Number of considered synthons: 135201
#
#
# Pocket model: alphafold3_P9WFS9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 207612
# Number of considered synthons: 130117
#
#
# Pocket model: alphafold3_P9WFS9_model_1_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 202005
# Number of considered synthons: 131486
#
#
# Pocket model: alphafold3_P9WFS9_model_1_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 359773
# Number of considered synthons: 131775
#
#
# Pocket model: alphafold3_P9WFS9_model_1_pocket_5
# Number of considered molecules: 100000
# Number of evaluated molecules: 163332
# Number of considered synthons: 125059
#
#
# Pocket model: alphafold3_P9WFS9_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 297978
# Number of considered synthons: 137661
#
#
# Pocket model: alphafold3_P9WFS9_model_2_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 223791
# Number of considered synthons: 133579
#
#
# Pocket model: alphafold3_P9WFS9_model_2_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 172915
# Number of considered synthons: 137070
#
#
# Pocket model: alphafold3_P9WFS9_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 304944
# Number of considered synthons: 136597
#
#
# Pocket model: alphafold3_P9WFS9_model_3_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 190403
# Number of considered synthons: 133434
#
#
# Pocket model: alphafold3_P9WFS9_model_3_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 190000
# Number of considered synthons: 137390
#
#
# Pocket model: alphafold3_P9WFS9_model_3_pocket_5
# Number of considered molecules: 100000
# Number of evaluated molecules: 185151
# Number of considered synthons: 133469
#
#
# Pocket model: alphafold3_P9WFS9_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 362391
# Number of considered synthons: 137300
#
#
# Pocket model: alphafold3_P9WFS9_model_4_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 181616
# Number of considered synthons: 134995
#
#
# Pocket model: alphafold3_P9WFS9_model_4_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 127899
# Number of considered synthons: 123474
#
#
# Pocket model: alphafold3_P9WFS9_model_4_pocket_5
# Number of considered molecules: 100000
# Number of evaluated molecules: 174316
# Number of considered synthons: 130310
#
#
# Pocket model: alphafold3_P9WFS9_model_4_pocket_6
# Number of considered molecules: 100000
# Number of evaluated molecules: 338672
# Number of considered synthons: 126408
#
#
# Pocket model: alphafold3_P9WFT1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 240113
# Number of considered synthons: 126692
#
#
# Pocket model: alphafold3_P9WFT1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 206766
# Number of considered synthons: 128560
#
#
# Pocket model: alphafold3_P9WFT1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 218077
# Number of considered synthons: 128217
#
#
# Pocket model: alphafold3_P9WFT3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 251856
# Number of considered synthons: 129396
#
#
# Pocket model: alphafold3_P9WFT3_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 268995
# Number of considered synthons: 125450
#
#
# Pocket model: alphafold3_P9WFT3_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 354949
# Number of considered synthons: 128146
#
#
# Pocket model: alphafold3_P9WFT5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 333813
# Number of considered synthons: 128559
#
#
# Pocket model: alphafold3_P9WFT5_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 167962
# Number of considered synthons: 126290
#
#
# Pocket model: alphafold3_P9WFT5_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 331303
# Number of considered synthons: 131852
#
#
# Pocket model: alphafold3_P9WFT5_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 170539
# Number of considered synthons: 126729
#
#
# Pocket model: alphafold3_P9WFT5_model_2_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 370099
# Number of considered synthons: 130771
#
#
# Pocket model: alphafold3_P9WFT5_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 154045
# Number of considered synthons: 118504
#
#
# Pocket model: alphafold3_P9WFT5_model_3_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 374116
# Number of considered synthons: 131577
#
#
# Pocket model: alphafold3_P9WFT5_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 511791
# Number of considered synthons: 128425
#
#
# Pocket model: alphafold3_P9WFT5_model_3_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 272130
# Number of considered synthons: 128684
#
#
# Pocket model: alphafold3_P9WFT5_model_4_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 321716
# Number of considered synthons: 126331
#
#
# Pocket model: alphafold3_P9WFT5_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 213318
# Number of considered synthons: 130871
#
#
# Pocket model: alphafold3_P9WFT5_model_4_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 299562
# Number of considered synthons: 131746
#
#
# Pocket model: alphafold3_P9WFT7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 187995
# Number of considered synthons: 131625
#
#
# Pocket model: alphafold3_P9WFT7_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 193979
# Number of considered synthons: 126623
#
#
# Pocket model: alphafold3_P9WFT7_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 200100
# Number of considered synthons: 136768
#
#
# Pocket model: alphafold3_P9WFT7_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 213404
# Number of considered synthons: 133745
#
#
# Pocket model: alphafold3_P9WFT9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 155076
# Number of considered synthons: 128958
#
#
# Pocket model: alphafold3_P9WFT9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 131714
# Number of considered synthons: 133821
#
#
# Pocket model: alphafold3_P9WFT9_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 171713
# Number of considered synthons: 128707
#
#
# Pocket model: alphafold3_P9WFT9_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 260269
# Number of considered synthons: 129370
#
#
# Pocket model: alphafold3_P9WFT9_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 142251
# Number of considered synthons: 124374
#
#
# Pocket model: alphafold3_P9WFU1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 421662
# Number of considered synthons: 128880
#
#
# Pocket model: alphafold3_P9WFU1_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 479118
# Number of considered synthons: 141267
#
#
# Pocket model: alphafold3_P9WFU1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 280616
# Number of considered synthons: 131583
#
#
# Pocket model: alphafold3_P9WFU1_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 289105
# Number of considered synthons: 131950
#
#
# Pocket model: alphafold3_P9WFU1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 205722
# Number of considered synthons: 127928
#
#
# Pocket model: alphafold3_P9WFU1_model_4_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 222882
# Number of considered synthons: 131876
#
#
# Pocket model: alphafold3_P9WFU3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 221349
# Number of considered synthons: 127741
#
#
# Pocket model: alphafold3_P9WFU3_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 337638
# Number of considered synthons: 128401
#
#
# Pocket model: alphafold3_P9WFU3_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 264066
# Number of considered synthons: 127586
#
#
# Pocket model: alphafold3_P9WFU3_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 205335
# Number of considered synthons: 126448
#
#
# Pocket model: alphafold3_P9WFU3_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 196890
# Number of considered synthons: 119299
#
#
# Pocket model: alphafold3_P9WFU5_model_2_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 484129
# Number of considered synthons: 126052
#
#
# Pocket model: alphafold3_P9WFU5_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 373204
# Number of considered synthons: 128081
#
#
# Pocket model: alphafold3_P9WFU9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 191253
# Number of considered synthons: 130142
#
#
# Pocket model: alphafold3_P9WFU9_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 189622
# Number of considered synthons: 128674
#
#
# Pocket model: alphafold3_P9WFU9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 149026
# Number of considered synthons: 127310
#
#
# Pocket model: alphafold3_P9WFV1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 195721
# Number of considered synthons: 131281
#
#
# Pocket model: alphafold3_P9WFV1_model_1_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 223015
# Number of considered synthons: 138494
#
#
# Pocket model: alphafold3_P9WFV1_model_2_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 475291
# Number of considered synthons: 140834
#
#
# Pocket model: alphafold3_P9WFV1_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 273662
# Number of considered synthons: 128482
#
#
# Pocket model: alphafold3_P9WFV1_model_4_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 369732
# Number of considered synthons: 124082
#
#
# Pocket model: alphafold3_P9WFV3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 336026
# Number of considered synthons: 137711
#
#
# Pocket model: alphafold3_P9WFV3_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 217749
# Number of considered synthons: 130831
#
#
# Pocket model: alphafold3_P9WFV3_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 279122
# Number of considered synthons: 128575
#
#
# Pocket model: alphafold3_P9WFV3_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 340726
# Number of considered synthons: 135845
#
#
# Pocket model: alphafold3_P9WFV3_model_2_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 159441
# Number of considered synthons: 123427
#
#
# Pocket model: alphafold3_P9WFV3_model_3_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 247517
# Number of considered synthons: 126660
#
#
# Pocket model: alphafold3_P9WFV3_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 337158
# Number of considered synthons: 135414
#
#
# Pocket model: alphafold3_P9WFV3_model_4_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 261008
# Number of considered synthons: 131452
#
#
# Pocket model: alphafold3_P9WFV7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 139554
# Number of considered synthons: 128061
#
#
# Pocket model: alphafold3_P9WFV7_model_3_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 176476
# Number of considered synthons: 131007
#
#
# Pocket model: alphafold3_P9WFV7_model_4_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 231645
# Number of considered synthons: 131441
#
#
# Pocket model: alphafold3_P9WFV9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 179445
# Number of considered synthons: 124869
#
#
# Pocket model: alphafold3_P9WFV9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 207386
# Number of considered synthons: 132920
#
#
# Pocket model: alphafold3_P9WFV9_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 397248
# Number of considered synthons: 133090
#
#
# Pocket model: alphafold3_P9WFV9_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 332528
# Number of considered synthons: 130357
#
#
# Pocket model: alphafold3_P9WFV9_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 238897
# Number of considered synthons: 132238
#
#
# Pocket model: alphafold3_P9WFW1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 531785
# Number of considered synthons: 132163
#
#
# Pocket model: alphafold3_P9WFW1_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 267326
# Number of considered synthons: 134067
#
#
# Pocket model: alphafold3_P9WFW1_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 213342
# Number of considered synthons: 129980
#
#
# Pocket model: alphafold3_P9WFW1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 137627
# Number of considered synthons: 113921
#
#
# Pocket model: alphafold3_P9WFW3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 223581
# Number of considered synthons: 128898
#
#
# Pocket model: alphafold3_P9WFW3_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 165088
# Number of considered synthons: 125046
#
#
# Pocket model: alphafold3_P9WFW3_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 389252
# Number of considered synthons: 130117
#
#
# Pocket model: alphafold3_P9WFW3_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 132760
# Number of considered synthons: 125299
#
#
# Pocket model: alphafold3_P9WFW3_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 396726
# Number of considered synthons: 132017
#
#
# Pocket model: alphafold3_P9WFW7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 191890
# Number of considered synthons: 131815
#
#
# Pocket model: alphafold3_P9WFW7_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 354786
# Number of considered synthons: 129930
#
#
# Pocket model: alphafold3_P9WFW7_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 187295
# Number of considered synthons: 133821
#
#
# Pocket model: alphafold3_P9WFW7_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 285591
# Number of considered synthons: 132313
#
#
# Pocket model: alphafold3_P9WQA1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 122004
# Number of considered synthons: 122363
#
#
# Pocket model: alphafold3_P9WQA1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 522230
# Number of considered synthons: 127461
#
#
# Pocket model: alphafold3_P9WQA1_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 228985
# Number of considered synthons: 131163
#
#
# Pocket model: alphafold3_P9WQA1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 474620
# Number of considered synthons: 140743
#
#
# Pocket model: alphafold3_P9WQA1_model_2_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 296165
# Number of considered synthons: 128295
#
#
# Pocket model: alphafold3_P9WQA1_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 131660
# Number of considered synthons: 129409
#
#
# Pocket model: alphafold3_P9WQA1_model_3_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 409365
# Number of considered synthons: 125627
#
#
# Pocket model: alphafold3_P9WQA1_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 473282
# Number of considered synthons: 140557
#
#
# Pocket model: alphafold3_P9WQA1_model_4_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 400489
# Number of considered synthons: 127925
#
#
# Pocket model: alphafold3_P9WQA1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 135856
# Number of considered synthons: 137328
#
#
# Pocket model: chai1_P9WFS9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 317496
# Number of considered synthons: 135210
#
#
# Pocket model: chai1_P9WFS9_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 242399
# Number of considered synthons: 130681
#
#
# Pocket model: chai1_P9WFS9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 357115
# Number of considered synthons: 131838
#
#
# Pocket model: chai1_P9WFS9_model_1_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 188128
# Number of considered synthons: 130725
#
#
# Pocket model: chai1_P9WFS9_model_2_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 225193
# Number of considered synthons: 136495
#
#
# Pocket model: chai1_P9WFS9_model_2_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 268426
# Number of considered synthons: 134950
#
#
# Pocket model: chai1_P9WFS9_model_3_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 193082
# Number of considered synthons: 125497
#
#
# Pocket model: chai1_P9WFS9_model_3_pocket_6
# Number of considered molecules: 100000
# Number of evaluated molecules: 212898
# Number of considered synthons: 128886
#
#
# Pocket model: chai1_P9WFS9_model_4_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 229311
# Number of considered synthons: 135379
#
#
# Pocket model: chai1_P9WFS9_model_4_pocket_5
# Number of considered molecules: 100000
# Number of evaluated molecules: 265257
# Number of considered synthons: 138791
#
#
# Pocket model: chai1_P9WFT1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 189716
# Number of considered synthons: 130514
#
#
# Pocket model: chai1_P9WFT1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 256671
# Number of considered synthons: 120755
#
#
# Pocket model: chai1_P9WFT1_model_2_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 216850
# Number of considered synthons: 133093
#
#
# Pocket model: chai1_P9WFT1_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 329604
# Number of considered synthons: 128618
#
#
# Pocket model: chai1_P9WFT1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 189561
# Number of considered synthons: 126068
#
#
# Pocket model: chai1_P9WFT3_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 267567
# Number of considered synthons: 127547
#
#
# Pocket model: chai1_P9WFT3_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 356212
# Number of considered synthons: 130418
#
#
# Pocket model: chai1_P9WFT5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 416954
# Number of considered synthons: 131231
#
#
# Pocket model: chai1_P9WFT5_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 186538
# Number of considered synthons: 127348
#
#
# Pocket model: chai1_P9WFT5_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 172472
# Number of considered synthons: 129592
#
#
# Pocket model: chai1_P9WFT5_model_1_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 231730
# Number of considered synthons: 129994
#
#
# Pocket model: chai1_P9WFT5_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 202741
# Number of considered synthons: 129066
#
#
# Pocket model: chai1_P9WFT5_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 196295
# Number of considered synthons: 119356
#
#
# Pocket model: chai1_P9WFT5_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 166015
# Number of considered synthons: 121594
#
#
# Pocket model: chai1_P9WFT7_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 420474
# Number of considered synthons: 126683
#
#
# Pocket model: chai1_P9WFT7_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 196467
# Number of considered synthons: 123605
#
#
# Pocket model: chai1_P9WFT7_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 311242
# Number of considered synthons: 132396
#
#
# Pocket model: chai1_P9WFT7_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 251741
# Number of considered synthons: 134835
#
#
# Pocket model: chai1_P9WFT9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 184516
# Number of considered synthons: 122188
#
#
# Pocket model: chai1_P9WFT9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 146835
# Number of considered synthons: 131540
#
#
# Pocket model: chai1_P9WFT9_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 158256
# Number of considered synthons: 130880
#
#
# Pocket model: chai1_P9WFT9_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 122190
# Number of considered synthons: 122606
#
#
# Pocket model: chai1_P9WFU1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 241975
# Number of considered synthons: 124631
#
#
# Pocket model: chai1_P9WFU1_model_3_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 157955
# Number of considered synthons: 129565
#
#
# Pocket model: chai1_P9WFU9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 174410
# Number of considered synthons: 133335
#
#
# Pocket model: chai1_P9WFV1_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 239353
# Number of considered synthons: 129111
#
#
# Pocket model: chai1_P9WFV1_model_1_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 184132
# Number of considered synthons: 132451
#
#
# Pocket model: chai1_P9WFV1_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 198115
# Number of considered synthons: 127656
#
#
# Pocket model: chai1_P9WFV1_model_3_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 264732
# Number of considered synthons: 129784
#
#
# Pocket model: chai1_P9WFV1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 254306
# Number of considered synthons: 127988
#
#
# Pocket model: chai1_P9WFV3_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 243059
# Number of considered synthons: 140165
#
#
# Pocket model: chai1_P9WFV3_model_1_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 227144
# Number of considered synthons: 124123
#
#
# Pocket model: chai1_P9WFV3_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 173550
# Number of considered synthons: 130670
#
#
# Pocket model: chai1_P9WFV3_model_2_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 221394
# Number of considered synthons: 136292
#
#
# Pocket model: chai1_P9WFV3_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 281545
# Number of considered synthons: 132829
#
#
# Pocket model: chai1_P9WFV3_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 185834
# Number of considered synthons: 134386
#
#
# Pocket model: chai1_P9WFV5_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 374386
# Number of considered synthons: 123541
#
#
# Pocket model: chai1_P9WFV7_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 303415
# Number of considered synthons: 131046
#
#
# Pocket model: chai1_P9WFV9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 355547
# Number of considered synthons: 122959
#
#
# Pocket model: chai1_P9WFV9_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 317226
# Number of considered synthons: 126790
#
#
# Pocket model: chai1_P9WFV9_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 318623
# Number of considered synthons: 124752
#
#
# Pocket model: chai1_P9WFV9_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 212871
# Number of considered synthons: 123895
#
#
# Pocket model: chai1_P9WFV9_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 273088
# Number of considered synthons: 123589
#
#
# Pocket model: chai1_P9WFW1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 254848
# Number of considered synthons: 127572
#
#
# Pocket model: chai1_P9WFW3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 215390
# Number of considered synthons: 135003
#
#
# Pocket model: chai1_P9WFW3_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 350479
# Number of considered synthons: 129187
#
#
# Pocket model: chai1_P9WFW3_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 277882
# Number of considered synthons: 124298
#
#
# Pocket model: chai1_P9WFW3_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 184177
# Number of considered synthons: 126308
#
#
# Pocket model: chai1_P9WFW3_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 268752
# Number of considered synthons: 127431
#
#
# Pocket model: chai1_P9WFW5_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 320901
# Number of considered synthons: 126279
#
#
# Pocket model: chai1_P9WN61_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 266240
# Number of considered synthons: 135408
#
#
# Pocket model: chai1_P9WN61_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 248410
# Number of considered synthons: 130214
#
#
# Pocket model: chai1_P9WN61_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 152034
# Number of considered synthons: 130199
#
#
# Pocket model: chai1_P9WQA1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 139674
# Number of considered synthons: 112054
#
#
# Pocket model: chai1_P9WQA1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 331901
# Number of considered synthons: 133018
#
#
# Pocket model: chai1_P9WQA1_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 198594
# Number of considered synthons: 127307
#
#
# Pocket model: chai1_P9WQA1_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 165666
# Number of considered synthons: 131850
#
#
# Pocket model: chai1_P9WQA1_model_2_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 187801
# Number of considered synthons: 135862
#
#
# Pocket model: chai1_P9WQA1_model_2_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 180485
# Number of considered synthons: 129013
#
#
# Pocket model: chai1_P9WQA1_model_3_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 319917
# Number of considered synthons: 119801
#
#
# Pocket model: chai1_P9WQA1_model_3_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 185995
# Number of considered synthons: 124883
#
#
# Pocket model: chai1_P9WQA1_model_4_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 180340
# Number of considered synthons: 129379
#
#
# Pocket model: chai1_P9WQA1_model_4_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 240592
# Number of considered synthons: 128534
#
#
# Pocket model: swissmodel_P9WFS9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 193951
# Number of considered synthons: 127994
#
#
# Pocket model: swissmodel_P9WFS9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 256733
# Number of considered synthons: 134516
#
#
# Pocket model: swissmodel_P9WFS9_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 195638
# Number of considered synthons: 135829
#
#
# Pocket model: swissmodel_P9WFS9_model_0_pocket_4
# Number of considered molecules: 100000
# Number of evaluated molecules: 175684
# Number of considered synthons: 121873
#
#
# Pocket model: swissmodel_P9WFS9_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 208719
# Number of considered synthons: 123731
#
#
# Pocket model: swissmodel_P9WFS9_model_1_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 212187
# Number of considered synthons: 124523
#
#
# Pocket model: swissmodel_P9WFT1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 207364
# Number of considered synthons: 136872
#
#
# Pocket model: swissmodel_P9WFT1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 354135
# Number of considered synthons: 135076
#
#
# Pocket model: swissmodel_P9WFT3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 230955
# Number of considered synthons: 134248
#
#
# Pocket model: swissmodel_P9WFT3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 186316
# Number of considered synthons: 133176
#
#
# Pocket model: swissmodel_P9WFT5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 216699
# Number of considered synthons: 128135
#
#
# Pocket model: swissmodel_P9WFT5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 217103
# Number of considered synthons: 122854
#
#
# Pocket model: swissmodel_P9WFT7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 308671
# Number of considered synthons: 130768
#
#
# Pocket model: swissmodel_P9WFT7_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 263129
# Number of considered synthons: 123661
#
#
# Pocket model: swissmodel_P9WFT9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 381517
# Number of considered synthons: 126762
#
#
# Pocket model: swissmodel_P9WFT9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 211198
# Number of considered synthons: 127258
#
#
# Pocket model: swissmodel_P9WFU1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 525937
# Number of considered synthons: 127795
#
#
# Pocket model: swissmodel_P9WFU1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 219432
# Number of considered synthons: 124355
#
#
# Pocket model: swissmodel_P9WFU1_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 234557
# Number of considered synthons: 132553
#
#
# Pocket model: swissmodel_P9WFU3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 218620
# Number of considered synthons: 134797
#
#
# Pocket model: swissmodel_P9WFU3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 270098
# Number of considered synthons: 130780
#
#
# Pocket model: swissmodel_P9WFU5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 308951
# Number of considered synthons: 134039
#
#
# Pocket model: swissmodel_P9WFU9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 324988
# Number of considered synthons: 128232
#
#
# Pocket model: swissmodel_P9WFU9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 218305
# Number of considered synthons: 125335
#
#
# Pocket model: swissmodel_P9WFV1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 225634
# Number of considered synthons: 128445
#
#
# Pocket model: swissmodel_P9WFV1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 226166
# Number of considered synthons: 125236
#
#
# Pocket model: swissmodel_P9WFV1_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 261592
# Number of considered synthons: 132685
#
#
# Pocket model: swissmodel_P9WFV1_model_0_pocket_5
# Number of considered molecules: 100000
# Number of evaluated molecules: 213490
# Number of considered synthons: 127583
#
#
# Pocket model: swissmodel_P9WFV1_model_1_pocket_6
# Number of considered molecules: 100000
# Number of evaluated molecules: 360077
# Number of considered synthons: 129091
#
#
# Pocket model: swissmodel_P9WFV3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 454215
# Number of considered synthons: 134016
#
#
# Pocket model: swissmodel_P9WFV3_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 177989
# Number of considered synthons: 127446
#
#
# Pocket model: swissmodel_P9WFV3_model_1_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 200288
# Number of considered synthons: 128363
#
#
# Pocket model: swissmodel_P9WFV5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 363097
# Number of considered synthons: 123969
#
#
# Pocket model: swissmodel_P9WFV5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 260644
# Number of considered synthons: 134478
#
#
# Pocket model: swissmodel_P9WFV5_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 245263
# Number of considered synthons: 125938
#
#
# Pocket model: swissmodel_P9WFV7_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 288670
# Number of considered synthons: 128628
#
#
# Pocket model: swissmodel_P9WFV7_model_1_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 171159
# Number of considered synthons: 126810
#
#
# Pocket model: swissmodel_P9WFV9_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 254471
# Number of considered synthons: 125820
#
#
# Pocket model: swissmodel_P9WFV9_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 292467
# Number of considered synthons: 128566
#
#
# Pocket model: swissmodel_P9WFW1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 205373
# Number of considered synthons: 128954
#
#
# Pocket model: swissmodel_P9WFW1_model_0_pocket_3
# Number of considered molecules: 100000
# Number of evaluated molecules: 331320
# Number of considered synthons: 131735
#
#
# Pocket model: swissmodel_P9WFW1_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 253238
# Number of considered synthons: 131029
#
#
# Pocket model: swissmodel_P9WFW3_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 155949
# Number of considered synthons: 137209
#
#
# Pocket model: swissmodel_P9WFW3_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 282761
# Number of considered synthons: 126119
#
#
# Pocket model: swissmodel_P9WFW5_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 258244
# Number of considered synthons: 122620
#
#
# Pocket model: swissmodel_P9WFW5_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 141832
# Number of considered synthons: 129720
#
#
# Pocket model: swissmodel_P9WFW7_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 218457
# Number of considered synthons: 131883
#
#
# Pocket model: swissmodel_P9WFW7_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 256299
# Number of considered synthons: 131617
#
#
# Pocket model: swissmodel_P9WN61_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 389553
# Number of considered synthons: 133931
#
#
# Pocket model: swissmodel_P9WQA1_model_0_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 298680
# Number of considered synthons: 136362
#
#
# Pocket model: swissmodel_P9WQA1_model_0_pocket_2
# Number of considered molecules: 100000
# Number of evaluated molecules: 165761
# Number of considered synthons: 122130
#
#
# Pocket model: swissmodel_P9WQA1_model_1_pocket_1
# Number of considered molecules: 100000
# Number of evaluated molecules: 140353
# Number of considered synthons: 121791

# %%
len(ALL_CONSIDERED_MOLECULES), len(ALL_CONSIDERED_SYNTHONS)
# Out:
# (276, 276)

# %%
len(set([j for pocket in ALL_CONSIDERED_MOLECULES for j in ALL_CONSIDERED_MOLECULES[pocket]]))
# Out:
# 2907538
