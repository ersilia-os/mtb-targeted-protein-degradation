# %%
import pandas as pd
import os

# %%
# Path to pocket data file
path_to_file = "../processed/pocket_detection_data_interpro.tsv"

# Load data
df = pd.read_csv(path_to_file, sep='\t')

# %%
df
# Out:
#      Uniprot AC                      File name Prediction type  \
# 0        P9WFS9  alphafold2_P9WFS9_model_0.pdb      alphafold2
# 1        P9WFS9  alphafold2_P9WFS9_model_0.pdb      alphafold2
# 2        P9WFS9  alphafold2_P9WFS9_model_0.pdb      alphafold2
# 3        P9WFS9  alphafold2_P9WFS9_model_0.pdb      alphafold2
# 4        P9WFS9  alphafold2_P9WFS9_model_0.pdb      alphafold2
# ...         ...                            ...             ...
# 1445     P9WQA1  swissmodel_P9WQA1_model_1.pdb      swissmodel
# 1446     P9WQA1  swissmodel_P9WQA1_model_1.pdb      swissmodel
# 1447     P9WQA1  swissmodel_P9WQA1_model_1.pdb      swissmodel
# 1448     P9WQA1  swissmodel_P9WQA1_model_1.pdb      swissmodel
# 1449     P9WQA1  swissmodel_P9WQA1_model_1.pdb      swissmodel
#
#                                               Full path  Pocket number  \
# 0     processed/aligned_relaxed_structures/P9WFS9/al...              1
# 1     processed/aligned_relaxed_structures/P9WFS9/al...              1
# 2     processed/aligned_relaxed_structures/P9WFS9/al...              1
# 3     processed/aligned_relaxed_structures/P9WFS9/al...              1
# 4     processed/aligned_relaxed_structures/P9WFS9/al...              2
# ...                                                 ...            ...
# 1445  processed/aligned_relaxed_structures/P9WQA1/sw...              1
# 1446  processed/aligned_relaxed_structures/P9WQA1/sw...              1
# 1447  processed/aligned_relaxed_structures/P9WQA1/sw...              1
# 1448  processed/aligned_relaxed_structures/P9WQA1/sw...              1
# 1449  processed/aligned_relaxed_structures/P9WQA1/sw...              1
#
#       Pocket score  Pocket probability Pocket centroid coordinate (x y z)  \
# 0            38.06               0.941              6.2831 10.2381 0.7746
# 1            38.06               0.941              6.2831 10.2381 0.7746
# 2            38.06               0.941              6.2831 10.2381 0.7746
# 3            38.06               0.941              6.2831 10.2381 0.7746
# 4             9.51               0.439               1.5045 28.3379 28.04
# ...            ...                 ...                                ...
# 1445          8.80               0.403              6.1464 4.7865 -6.0286
# 1446          8.80               0.403              6.1464 4.7865 -6.0286
# 1447          8.80               0.403              6.1464 4.7865 -6.0286
# 1448          8.80               0.403              6.1464 4.7865 -6.0286
# 1449          8.80               0.403              6.1464 4.7865 -6.0286
#
#                            Pocket residues (chain_resn)  \
# 0     A_196 A_197 A_356 A_357 A_415 A_417 A_454 A_45...
# 1     A_196 A_197 A_356 A_357 A_415 A_417 A_454 A_45...
# 2     A_196 A_197 A_356 A_357 A_415 A_417 A_454 A_45...
# 3     A_196 A_197 A_356 A_357 A_415 A_417 A_454 A_45...
# 4     A_207 A_225 A_226 A_227 A_228 A_271 A_276 A_28...
# ...                                                 ...
# 1445  A_130 A_131 A_132 A_133 A_177 A_178 A_180 A_31...
# 1446  A_130 A_131 A_132 A_133 A_177 A_178 A_180 A_31...
# 1447  A_130 A_131 A_132 A_133 A_177 A_178 A_180 A_31...
# 1448  A_130 A_131 A_132 A_133 A_177 A_178 A_180 A_31...
# 1449  A_130 A_131 A_132 A_133 A_177 A_178 A_180 A_31...
#
#                                               B-factors Interpro ID  \
# 0     68.89 77.77 82.22 81.33 95.63 94.36 94.63 93.5...   IPR001412
# 1     68.89 77.77 82.22 81.33 95.63 94.36 94.63 93.5...   IPR002300
# 2     68.89 77.77 82.22 81.33 95.63 94.36 94.63 93.5...   IPR002303
# 3     68.89 77.77 82.22 81.33 95.63 94.36 94.63 93.5...   IPR014729
# 4     94.03 93.87 94.03 93.34 94.63 92.76 83.09 95.0...   IPR002300
# ...                                                 ...         ...
# 1445  0.89 0.85 0.88 0.88 0.9 0.9 0.9 0.87 0.85 0.88...   IPR000120
# 1446  0.89 0.85 0.88 0.88 0.9 0.9 0.9 0.87 0.85 0.88...   IPR004412
# 1447  0.89 0.85 0.88 0.88 0.9 0.9 0.9 0.87 0.85 0.88...   IPR020556
# 1448  0.89 0.85 0.88 0.88 0.9 0.9 0.9 0.87 0.85 0.88...   IPR023631
# 1449  0.89 0.85 0.88 0.88 0.9 0.9 0.9 0.87 0.85 0.88...   IPR036928
#
#                                           Interpro name  \
# 0     Aminoacyl-tRNA synthetase, class I, conserved ...
# 1                   Aminoacyl-tRNA synthetase, class Ia
# 2                                    Valine-tRNA ligase
# 3          Rossmann-like alpha/beta/alpha sandwich fold
# 4                   Aminoacyl-tRNA synthetase, class Ia
# ...                                                 ...
# 1445                                            Amidase
# 1446      Glutamyl-tRNA(Gln) amidotransferase A subunit
# 1447                            Amidase, conserved site
# 1448                           Amidase signature domain
# 1449                 Amidase signature (AS) superfamily
#
#                      Interpro Matches  Residues in pocket  \
# 0                      [['53', '64']]                  38
# 1     [['25', '436'], ['446', '579']]                  38
# 2                     [['11', '886']]                  38
# 3     [['14', '225'], ['309', '537']]                  38
# 4     [['25', '436'], ['446', '579']]                  15
# ...                               ...                 ...
# 1445                   [['3', '485']]                  14
# 1446                  [['12', '488']]                  14
# 1447                 [['154', '185']]                  14
# 1448                  [['25', '476']]                  14
# 1449                   [['1', '488']]                  14
#
#       Residues in interpro  Residues overlap  Coverage pocket  Coverage domain
# 0                       12                 7             0.18             0.58
# 1                      546                38             1.00             0.07
# 2                      876                38             1.00             0.04
# 3                      441                34             0.89             0.08
# 4                      546                15             1.00             0.03
# ...                    ...               ...              ...              ...
# 1445                   483                14             1.00             0.03
# 1446                   477                14             1.00             0.03
# 1447                    32                 3             0.21             0.09
# 1448                   452                14             1.00             0.03
# 1449                   488                14             1.00             0.03
#
# [1450 rows x 18 columns]
