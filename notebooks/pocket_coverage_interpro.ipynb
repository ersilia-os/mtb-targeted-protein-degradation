# %%
import pandas as pd
import os

# %%
# Path to pocket data file
path_to_file = "../processed/pocket_detection_data_interpro.tsv"

# Load data
columns = ["Uniprot AC", "File name", "Pocket number", "Pocket score", "Pocket probability", "Pocket centroid coordinate (x y z)", "Interpro ID", "Interpro name", "Interpro curated annotation",
           "Residues in pocket", "Residues in interpro", "Residues overlap", "Coverage pocket", "Coverage domain", "Overall coverage domain"]
df = pd.read_csv(path_to_file, sep='\t')[columns]

# %%
df[df['Uniprot AC'] == 'P9WFS9']
# Out:
#    Uniprot AC                      File name  Pocket number  Pocket score  \
# 0      P9WFS9  alphafold2_P9WFS9_model_0.pdb              1         38.06
# 1      P9WFS9  alphafold2_P9WFS9_model_0.pdb              1         38.06
# 2      P9WFS9  alphafold2_P9WFS9_model_0.pdb              2          9.51
# 3      P9WFS9  alphafold2_P9WFS9_model_0.pdb              2          9.51
# 4      P9WFS9  alphafold2_P9WFS9_model_0.pdb              3          7.95
# ..        ...                            ...            ...           ...
# 64     P9WFS9  swissmodel_P9WFS9_model_0.pdb              4          7.81
# 65     P9WFS9  swissmodel_P9WFS9_model_0.pdb              4          7.81
# 66     P9WFS9  swissmodel_P9WFS9_model_1.pdb              1         41.36
# 67     P9WFS9  swissmodel_P9WFS9_model_1.pdb              1         41.36
# 68     P9WFS9  swissmodel_P9WFS9_model_1.pdb              3          5.72
#
#     Pocket probability Pocket centroid coordinate (x y z) Interpro ID  \
# ...
