# %%
import os
import requests
from io import StringIO
from Bio.PDB.MMCIF2Dict import MMCIF2Dict

# %%
def get_assembly_details_online(pdb_id):
    # Fetch the mmCIF content from RCSB
    url = f"https://files.rcsb.org/download/{pdb_id.upper()}.cif"
    response = requests.get(url)
    
    if response.status_code != 200:
        raise ValueError(f"Could not fetch CIF file for {pdb_id}")
    
    # Parse mmCIF directly from the content string
    mmcif_dict = MMCIF2Dict(StringIO(response.text))
    
    # Extract stoichiometry and oligomeric details
    stoichiometry = mmcif_dict.get('_pdbx_struct_assembly.stoichiometry')
    oligomeric_details = mmcif_dict.get('_pdbx_struct_assembly.oligomeric_details')
    
    return stoichiometry, oligomeric_details

# %%
path = "../data/structures/pdbe_database/"
pdbs = [[uni,j] for uni in os.listdir(path) for j in os.listdir(os.path.join(path, uni, uni + '_archive-PDB')) if '.txt' not in j]

# %%
pdbs
# Out:
# [['P9WFW3', 'pdb5w25.ent'],
#  ['P9WFV1', 'pdb5ags.ent'],
#  ['P9WFV1', 'pdb5agr.ent'],
#  ['P9WFV1', 'pdb5agt.ent'],
#  ['P9WFV1', 'pdb7pqk.ent'],
#  ['P9WFU5', 'pdb6ax8.ent'],
#  ['P9WFU3', '7ka0_updated.cif'],
#  ['P9WFU3', '7db7_updated.cif'],
#  ['P9WFU3', '7daw_updated.cif'],
#  ['P9WFU3', '7k98_updated.cif'],
#  ['P9WFU3', '7kab_updated.cif'],
#  ['P9WFU3', '7k9m_updated.cif'],
#  ['P9WFU3', '7db8_updated.cif'],
#  ['P9WFV9', 'pdb2ja2.ent'],
#  ['P9WFV9', 'pdb3pnv.ent'],
#  ['P9WFV9', 'pdb3pny.ent'],
#  ['P9WFV7', '8t5n_updated.cif'],
#  ['P9WFV7', '8u2p_updated.cif'],
#  ['P9WFT3', 'pdb7el8.ent'],
#  ['P9WFT3', 'pdb7ev3.ent'],
#  ['P9WFT3', 'pdb7elt.ent'],
#  ['P9WFT3', 'pdb7ent.ent'],
#  ['P9WFT3', 'pdb7ev2.ent'],
#  ['P9WFT3', 'pdb7ens.ent'],
#  ['P9WFT1', 'pdb2jan.ent'],
#  ['P9WFU1', 'pdb7k98.ent'],
#  ['P9WFU1', 'pdb7daw.ent'],
#  ['P9WFU1', 'pdb7k9m.ent'],
#  ['P9WFU1', 'pdb7db8.ent'],
#  ['P9WFU1', 'pdb7kab.ent'],
#  ['P9WFU1', 'pdb7db7.ent'],
#  ['P9WFU1', 'pdb7ka0.ent'],
#  ['P9WFU9', '7qhn_updated.cif'],
#  ['P9WFU9', '7qi8_updated.cif'],
#  ['P9WFU9', '7qh8_updated.cif']]

# %%
pdbs = ['2jan', '7el8', '7elt', '7ens', '7ent', '7ev2', '7ev3']


for pdb in pdbs:
    stoich, oligomeric_details = get_assembly_details_online(pdb)
    print(pdb, stoich, oligomeric_details)
# Out:
# 2jan None ['dimeric', 'dimeric']
# 7el8 None ['dimeric']
# 7elt None ['dimeric']
# 7ens None ['dimeric']
# 7ent None ['dimeric']
# 7ev2 None ['dimeric']
# 7ev3 None ['dimeric']
