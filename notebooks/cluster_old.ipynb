# %%
df.to_csv(os.path.join(root, "processed", "unidock_REAL_docking", "inference_10B", "selected_compounds_synthon.csv"), index=False)

# %%
# df[df['id'].str.contains("23521810")][:50]

# %%
SYNTHON_COUNTS
# Out:
# defaultdict(int,
#             {'25037044': 3,
#              '13187268': 3,
#              '15858220': 3,
#              '23414938': 3,
#              '15962996': 3,
#              '15976146': 3,
#              '22175474': 3,
#              '14417596': 3,
#              '31574708': 3,
#              '24875740': 3,
#              '28580338': 1,
#              '28139450': 3,
#              '28610894': 3,
#              '22247592': 1,
#              '23868088': 3,
#              '28264176': 3,
#              '28618134': 3,
#              '17824818': 3,
#              '17915054': 2,
#              '15533548': 3,
#              '28759674': 3,
#              '23521934': 3,
#              '24981188': 3,
#              '15978024': 3,
#              '28244982': 3,
#              '28801908': 2,
#              '24320924': 3,
#              '24202700': 3,
#              '22204460': 1,
#              '28895010': 1,
#              '30225260': 3,
#              '24293518': 1,
# ...
