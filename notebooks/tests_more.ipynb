# %%
import h5py
import os

# %%
ids = open("../processed/enamine_REAL_characterization/enamine_REAL.csv", "r").readlines()

# %%
len(ids)
# Out:
# 9557695

# %%
len(set([i.split("\t")[0] for i in ids]))
# Out:
# 9557695

# %%
ids
# Out:
# ['InChiKey\tid\tsmiles\n',
#  'AAAABPZTFGUZFD-UHFFFAOYSA-N\ts_22____26254084____8751548\tCOC1=CC=CC(NNC(=O)C2=CC=CC(I)=C2O)=C1Cl\n',
#  'AAAABYONBKEFEA-BQYQJAHWSA-N\tm_276450____14192822____27789788____28201378\tCC1=NOC(/C=C/C(=O)N2CCC(NC3=CC(C4CCC4)=NC=N3)CC(C)(C)C2)=C1\n',
#  'AAAAFCAOAGWZRF-UHFFFAOYSA-N\tm_274552____23522442____25009882____15974666\tC=CCC(NC(=O)CC1=CN=C(C)S1)C(=O)NC1(C2=CSC=C2)CC1\n',
#  'AAAAFESOYKOALD-OXVDWMRYSA-N,AAAAFESOYKOALD-YMDOPBFCSA-N\tm_282030____21899256____22359982____21943440\tCCCOC1=CC=C2CN(C3=NC(NC4C[C@H]5CC(CO)C[C@@H]45)=NC4=C3NC=C4)CCC2=C1 |&1:16,22|\n',
#  'AAAAGGNQLAOYKH-UHFFFAOYSA-N\tm_274552____23520358____15966596____13453930\tCOC(CNC(=O)C1=NNC(=O)C=C1)CC(=O)N1CCCC2(C1)N=N2\n',
#  'AAAAGQRBEWFOCX-UHFFFAOYSA-N\ts_2708____23836994____913110\tCOC(=O)C1=CC=CC(C2=CC=CC(CNC(=O)N(C)CC3=CC=C(F)C=C3F)=C2)=C1\n',
# ...

# %%
[len(i.split("\t")[0]) for i in ids]
# Out:
# [8,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  55,
#  27,
#  55,
#  27,
#  27,
#  111,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  55,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
# ...

# %%
ids = [len(i.split("\t")[1]) for i in ids]

# %%
max(ids)
# Out:
# 44

# %%
ids = []
for c in range(0, 96):
    ids.extend(h5py.File("../processed/enamine_REAL_characterization/embeddings/enamine_REAL_chemeleon_chunk_0.h5")['ids'][:].astype(str))

# %%
max([len(i) for i in ids])
# Out:
# 32
