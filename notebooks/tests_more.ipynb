# %%
import h5py
import os

# %%
ids = open("../../../Documents/mtb-targeted-protein-degradation/processed/enamine_REAL_characterization/enamine_REAL.csv", "r").readlines()

# %%
len(ids)
# Out:
# 9557695

# %%
len(set([i.split("\t")[0] for i in ids]))
# Out:
# 9557695

# %%
[len(i.split("\t")[0]) for i in ids]
# Out:
# [8,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  55,
#  27,
#  55,
#  27,
#  27,
#  111,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  55,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  27,
#  55,
#  27,
#  27,
#  27,
#  27,
#  27,
# ...

# %%
max([len(i.split("\t")[1]) for i in ids])
# Out:
# 44

# %%
ids = []
for c in range(0, 10):
    ids.extend(h5py.File(f"../../../Documents_GPU/mtb-targeted-protein-degradation/processed/enamine_REAL_characterization/embeddings/enamine_REAL_chemeleon_chunk_{c}.h5")['ids'][:].astype(str))

# %%
max([len(i) for i in ids])
# Out:
# 44
