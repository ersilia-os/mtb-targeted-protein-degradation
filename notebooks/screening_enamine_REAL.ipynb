# %%
from multiprocessing import Pool
from tqdm import tqdm
import pandas as pd
import numpy as np
import joblib
import time
import h5py
import os

# %%
root = "."

# Define paths - corresponding to the Ersilia GPU machine (embeddings) and SBNB filesystem (models)
BINS = ['bin_01', 'bin_05', 'bin_1'][::-1]
PATH_TO_MODELS = "/aloy/home/acomajuncosa/Ersilia/mtb/processed/unidock_docking/models"
PATH_TO_EMBEDDINGS = "/home/acomajuncosa/Documents/mtb-targeted-protein-degradation/processed/enamine_REAL_characterization/embeddings"
models = [[i, j] for i in sorted(os.listdir(PATH_TO_MODELS)) for j in BINS]

# %%
def process_model(model):

    # Define pocket and model
    pocket = model[0]
    bin = model[1]

    # Load the model
    PATH_TO_MODELS = "/aloy/home/acomajuncosa/Ersilia/mtb/processed/unidock_docking/models"
    model_path = os.path.join(PATH_TO_MODELS, pocket, bin, "LQ_RF.joblib")
    model = joblib.load(model_path)

    

    time.sleep(1)
    return a

# # Load ids and X
# with h5py.File(os.path.join(PATH_TO_EMBEDDINGS, chunk), 'r') as f:
#     ids = f['ids'][:]
#     X = f['X'][:]

# %%
# Use multiprocessing to process models in parallel
with Pool(processes=8) as pool:
    results = list(tqdm(pool.imap(process_model, models), total=len(models)))
# Out:
# 100%|██████████| 147/147 [00:19<00:00,  7.74it/s]

# %%
# For each pocket
for pocket in ):

    # For each bin
    for bin in BINS:

        

        # For each chunk in embeddings (size 100k)
        sorted_chunks = sorted(os.listdir(PATH_TO_EMBEDDINGS), key=lambda x: int(x.split("_")[-1].split(".")[0]))
        args = [(os.path.join(PATH_TO_EMBEDDINGS, chunk), model) for chunk in sorted_chunks]

        



        break
    break
# Out:
# 100%|██████████| 57/57 [00:45<00:00,  1.24it/s]
