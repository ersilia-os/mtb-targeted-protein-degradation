# %%
import pandas as pd
import numpy as np
import lazyqsar
import tl2cgen
import treelite
import joblib
import pickle
import tqdm
import time
import h5py
import copy
import os

# %%
PATH_TO_MODELS = "/aloy/home/acomajuncosa/Ersilia/mtb/processed/unidock_docking/models"
sizes = []

# Get the sizes of the models
for pocket in tqdm.tqdm(sorted(os.listdir(PATH_TO_MODELS))):
    for bin in sorted(os.listdir(os.path.join(PATH_TO_MODELS, pocket))):
        try:
            sizes.append(os.path.getsize(os.path.join(PATH_TO_MODELS, pocket, bin, "LQ_RF.joblib")) / (1000 * 1000))
        except:
            pass
# Out:
# 100%|██████████| 274/274 [00:10<00:00, 26.96it/s]

# %%
np.min(sizes), np.max(sizes), np.median(sizes)
# Out:
# (38.760939, 328.403147, 154.127635)

# %%
PATH_TO_MODELS = "/aloy/home/acomajuncosa/Ersilia/mtb/processed/unidock_docking/models"
PATH_TO_COMPILED_MODELS = "/home/acomajuncosa/Documents/mtb-targeted-protein-degradation/processed/unidock_docking/compiled_models"
pocket = "alphafold2_P9WFS9_model_0_pocket_1"
bin = "bin_05"

# Load the model
model = joblib.load(os.path.join(PATH_TO_MODELS, pocket, bin, "LQ_RF.joblib"))

# Print the size of the model
print(f"Size of the model: {os.path.getsize(os.path.join(PATH_TO_MODELS, pocket, bin, 'LQ_RF.joblib')) / (1000 * 1000)} MB")
# Out:
# Size of the model: 132.306763 MB

# %%
# Load some SMILES
PATH_TO_MFPS = "../processed/enamine_characterization"
IK_TO_SMILES = pickle.load(open(os.path.join(PATH_TO_MFPS, "IK_TO_SMI.pkl"), "rb"))
SMILES = np.array(list(IK_TO_SMILES.values())[:100])

# Load X CheMeleon
X = np.load(os.path.join(PATH_TO_MFPS, "X_CheMeleon.npz"))['X']

# %%
# Load CheMeleon descriptors
with h5py.File(os.path.join("../processed/enamine_REAL_characterization/embeddings/", "enamine_REAL_chemeleon_chunk_0.h5"), "r") as f:
    X, ids = f['X'][:50000], f['ids']

print(f"Number of compounds: {len(X)}")
# Out:
# Number of compounds: 50000

# %%
start = time.time()
preds = model.predict_proba(X)
end = time.time()
print(f"Prediction time: {end - start:.2f} seconds")
# Out:
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:09,  5.53it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:09,  5.39it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:08,  5.89it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:08,  6.17it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:09,  5.14it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:09,  5.33it/s]
# ...

# %%
# model_to_compile = copy.deepcopy(model)
# model_to_compile.model.models[0].model_.n_jobs

# %%
for mm in model.model.models:
    mm.model_.n_jobs = 1

# %%
model.model.models[0].model_.n_jobs
# Out:
# 1

# %%
start = time.time()
preds = model.predict_proba(X)
end = time.time()
print(f"Prediction time: {end - start:.2f} secomodelnds")
# Out:
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 19.59it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 20.39it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 19.54it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 20.87it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 20.51it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 20.45it/s]
# ...

# %%
# from sklearnex import patch_sklearn
# patch_sklearn() 

# start = time.time()
# preds = model_to_compile.predict_proba(X)
# end = time.time()
# print(f"Prediction time: {end - start:.2f} seconds")

# %%
model_to_compile = copy.deepcopy(model)

# %%
import os
import sys
import numpy as np
import treelite
import tl2cgen
from types import MethodType
from sklearn.ensemble import RandomForestClassifier

# -------------------- helpers --------------------

def _choose_toolchain():
    # Allow override via env; otherwise pick a sensible default per OS
    tc = os.environ.get("TL2CGEN_TOOLCHAIN")
    if tc:
        return tc
    if os.name == "nt":
        return "msvc"
    if sys.platform == "darwin":
        return "clang"
    return "gcc"

def _libname_for_platform():
    if os.name == "nt":
        return "predictor.dll"
    return "predictor.dylib" if sys.platform == "darwin" else "predictor.so"

# -------------------- compile & runtime shims --------------------

def _compile_tl2cgen_lib(tl_model, out_dir, parallel_comp: int):
    """
    Compile a treelite.Model to a native shared library using TL2cgen.
    Returns the absolute path to the compiled library.
    """
    os.makedirs(out_dir, exist_ok=True)
    toolchain = _choose_toolchain()
    libname = _libname_for_platform()
    libpath = os.path.join(out_dir, libname)
    # TL2cgen expects strings for some params; be safe and cast
    tl2cgen.export_lib(
        tl_model,
        toolchain=toolchain,
        libpath=libpath,
        params={"parallel_comp": int(parallel_comp)},
        verbose=False,
    )
    if not os.path.exists(libpath):
        # As a fallback, pick any produced .so/.dylib/.dll in out_dir
        for name in os.listdir(out_dir):
            if name.endswith((".so", ".dylib", ".dll")):
                libpath = os.path.join(out_dir, name)
                break
    if not os.path.exists(libpath):
        raise RuntimeError("TL2cgen did not emit a shared library. Check toolchain and permissions.")
    return os.path.abspath(libpath)

def _tl_predict_proba(self, X):
    """
    TL2cgen predict_proba shim for sklearn RF.
    Handles (N,2), (N,1,2), (N,), (N,1).
    Always returns (N,2).
    """
    X = np.asarray(X, dtype=np.float32, order="C")
    dmat = tl2cgen.DMatrix(X)
    raw = self._tl_predictor.predict(dmat, pred_margin=False)
    raw = np.asarray(raw, dtype=np.float32)

    # Case A: Already (N,2)
    if raw.ndim == 2 and raw.shape[1] == 2:
        probs = raw

    # Case B: (N,1,2) → squeeze out middle dim
    elif raw.ndim == 3 and raw.shape[1] == 1 and raw.shape[2] == 2:
        probs = raw[:, 0, :]

    # Case C: (N,) or (N,1) → only positive class given
    elif raw.ndim == 1 or (raw.ndim == 2 and raw.shape[1] == 1):
        p1 = raw.reshape(-1)
        probs = np.stack([1.0 - p1, p1], axis=1)

    else:
        raise RuntimeError(f"Unexpected TL2cgen output shape {raw.shape}")

    # sanity check
    assert probs.shape == (X.shape[0], 2), (
        f"predict_proba mismatch: got {probs.shape}, expected ({X.shape[0]}, 2)"
    )
    return probs




def compile_rf_inplace(rf: RandomForestClassifier, out_dir: str, parallel_comp: int = 16):
    """
    Compile ONE sklearn RandomForestClassifier with TL2cgen and patch its predict_proba.
    """
    # Import sklearn model into a Treelite model (Treelite 4.x still provides this)
    tl_model = treelite.sklearn.import_model(rf)
    lib_path = _compile_tl2cgen_lib(tl_model, out_dir, parallel_comp)
    # Create TL2cgen runtime predictor and patch the RF instance
    rf._tl_predictor = tl2cgen.Predictor(lib_path)
    rf.predict_proba = MethodType(_tl_predict_proba, rf)
    return rf

# -------------------- walk your LazyQSAR object --------------------

def _walk_objects(obj, seen):
    """
    Recursively find sklearn RandomForestClassifier instances inside any Python object.
    """
    if id(obj) in seen:
        return []
    seen.add(id(obj))
    found = []
    if isinstance(obj, RandomForestClassifier):
        found.append(obj)
        return found
    # Inspect attributes defensively
    for name in dir(obj):
        if name.startswith("_"):
            continue
        try:
            val = getattr(obj, name)
        except Exception:
            continue
        if isinstance(val, RandomForestClassifier):
            found.append(val)
        elif isinstance(val, (list, tuple, set)):
            for v in val:
                try:
                    found += _walk_objects(v, seen)
                except Exception:
                    pass
        elif isinstance(val, dict):
            for v in val.values():
                try:
                    found += _walk_objects(v, seen)
                except Exception:
                    pass
        else:
            try:
                found += _walk_objects(val, seen)
            except Exception:
                pass
    return found

def compile_all_forests_inplace(lazy_model, out_root="tl_artifacts", parallel_comp: int = 16):
    """
    Find every sklearn RF inside your LazyQSAR model and compile it in-place.
    Returns the number of unique RFs patched.
    """
    rfs = _walk_objects(lazy_model, seen=set())

    # De-duplicate by object id
    uniq_rfs, seen_ids = [], set()
    for rf in rfs:
        if id(rf) not in seen_ids:
            uniq_rfs.append(rf)
            seen_ids.add(id(rf))

    # Compile each RF and patch predict_proba
    for i, rf in enumerate(uniq_rfs):
        out_dir = os.path.join(out_root, f"rf_{i:03d}")
        os.makedirs(out_dir, exist_ok=True)
        compile_rf_inplace(rf, out_dir, parallel_comp)

    return len(uniq_rfs)

# %%
# 2. Compile all embedded RandomForests in-place
n = compile_all_forests_inplace(model_to_compile, out_root="tl_artifacts", parallel_comp=16)
print(f"Compiled and patched {n} RandomForest(s).")
# Out:
# [14:30:51] /tmp/tmpfk5q71dd/libbuild/_deps/treelite-src/src/serializer.cc:202: The model you are loading originated from a newer Treelite version; some functionalities may be unavailable.
# Currently running Treelite version 4.1.2
# The model checkpoint was generated from Treelite version 4.4.1
# [14:30:51] /project/src/compiler/ast/split.cc:35: Parallel compilation enabled; member trees will be divided into 16 translation units.
# [14:31:00] /tmp/tmpfk5q71dd/libbuild/_deps/treelite-src/src/serializer.cc:202: The model you are loading originated from a newer Treelite version; some functionalities may be unavailable.
# Currently running Treelite version 4.1.2
# The model checkpoint was generated from Treelite version 4.4.1
# [14:31:00] /project/src/compiler/ast/split.cc:35: Parallel compilation enabled; member trees will be divided into 16 translation units.
# ...

# %%
# 1. Grab an RF from each model
rf_orig = next(iter(_walk_objects(model, seen=set())))
rf_comp = next(iter(_walk_objects(model_to_compile, seen=set())))

# 2. Check if compiled
print("orig RF patched:", hasattr(rf_orig, "_tl_predictor"))
print("comp RF patched:", hasattr(rf_comp, "_tl_predictor"))

# 3. Functional comparison
import numpy as np
X_small = X
start = time.time()
p1 = model.predict_proba(X_small)
print(f"Original prediction time: {time.time() - start:.2f} seconds")
start = time.time()
p2 = model_to_compile.predict_proba(X_small)
print(f"Compiled prediction time: {time.time() - start:.2f} seconds")
print("max abs diff:", float(np.max(np.abs(p1 - p2))))
# Out:
# orig RF patched: False
# comp RF patched: True
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 18.89it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 19.72it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 19.21it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 19.88it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 20.10it/s]
# [VarianceThreshold(threshold=0)] BaseRandomForestBinaryClassifier(num_splits=1, num_trials=20, timeout=120)
# Predicting chunks...: 50it [00:02, 19.49it/s]
# ...

# %%
# class TL2cgenRFWrapper:
#     """Minimal sklearn-like wrapper for TL2cgen predictor."""
#     def __init__(self, libpath: str, nthread: int = 8):
#         self.libpath = libpath
#         self.predictor = tl2cgen.Predictor(libpath=libpath, nthread=nthread)

#     def predict_proba(self, X):
#         # Ensure float32 + contiguous for best speed
#         X = np.asarray(X, dtype=np.float32, order="C")
#         dmat = tl2cgen.DMatrix(X)
#         # For RF classification, set pred_margin=False to get probabilities
#         out = self.predictor.predict(dmat, pred_margin=False)
#         # TL2cgen may return shape (n_samples,) for binary, or (n_samples, 2).
#         out = np.asarray(out)
#         if out.ndim == 1:
#             p1 = out
#             p0 = 1.0 - p1
#             return np.column_stack([p0, p1])
#         return out  # already (n_samples, n_classes)
    

# for i, mm in enumerate(model_to_compile.model.models):

#     print(mm.model_)
#     tl_model = treelite.sklearn.import_model(mm.model_)
#     path_to_output = os.path.join(PATH_TO_COMPILED_MODELS, pocket, bin)
#     os.makedirs(path_to_output, exist_ok=True)
#     libpath = os.path.join(path_to_output, "model.so")
#     tl2cgen.export_lib(tl_model, toolchain="gcc", libpath=libpath, params={"parallel_comp": 8}, options=["-O3"])
#     model_to_compile.model.models[i].model_ = TL2cgenRFWrapper(libpath, nthread=8)


#     break

# %%
# start = time.time()
# preds = model_to_compile.predict_proba(X)
# end = time.time()
# print(f"Prediction time: {end - start:.2f} seconds")
